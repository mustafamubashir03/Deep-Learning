# %% [markdown]
# <a href="https://colab.research.google.com/github/mustafamubashir03/Deep-Learning/blob/main/Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
import os
os.environ['HF_TOKEN']=""

# %%
model_name='google/gemma-3-1b-it'

# %%
from transformers import AutoTokenizer,AutoModelForCausalLM

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
input_prompt = ["The capital of Pakistan is"]

# %%
tokenized = tokenizer(input_prompt,return_tensors="pt")

# %%
tokenized['input_ids']
# Out:
# tensor([[    2,   818,  5279,   529, 16584,   563]])

# %%
import torch
model = AutoModelForCausalLM.from_pretrained(model_name,dtype=torch.bfloat16)

# %%
gen_result = model.generate(tokenized['input_ids'],max_new_tokens=25)

# %%
output = tokenizer.batch_decode(gen_result)
print(output)
# Out:
# ["<bos>The capital of Pakistan is Islamabad.\n\nIt's important to note:  Pakistan is a country that has experienced significant political instability and has faced numerous"]
